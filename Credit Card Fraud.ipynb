# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 271282  164503.0  1.922044 -0.723320 -1.831078 -1.169380  0.803403  1.266419
# 271283  164504.0 -0.322881  1.164874  0.308291 -0.433456  0.969553 -0.603540
# 271284  164504.0 -0.717754  1.033083 -0.146104 -1.064620  1.133477  0.989543
# 271285  164504.0  2.037487 -0.045018 -3.057337  0.246962  2.944680  3.298262
# 271286  164505.0  1.792630 -1.247581 -2.565785 -0.535199  0.251652 -0.379364
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 271282 -0.362358  0.388426  1.736604  ...  0.208709  0.985213 -0.024339
# 271283  1.004928 -0.073840 -0.725387  ...  0.203458  0.628991 -0.662551
# 271284  0.410626  0.830524 -0.577077  ... -0.099268 -0.163939  0.050914
# 271285 -0.003798  0.675096  0.045968  ...  0.037895  0.228836  0.036609
# 271286  0.427056 -0.350000       NaN  ...       NaN       NaN       NaN
#
# ...

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271287 entries, 0 to 271286
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    271287 non-null  float64
#  1   V1      271287 non-null  float64
#  2   V2      271287 non-null  float64
#  3   V3      271287 non-null  float64
#  4   V4      271287 non-null  float64
#  5   V5      271287 non-null  float64
#  6   V6      271287 non-null  float64
#  7   V7      271287 non-null  float64
#  8   V8      271287 non-null  float64
#  9   V9      271286 non-null  float64
#  10  V10     271286 non-null  float64
#  11  V11     271286 non-null  float64
#  12  V12     271286 non-null  float64
#  13  V13     271286 non-null  float64
#  14  V14     271286 non-null  float64
#  15  V15     271286 non-null  float64
#  16  V16     271286 non-null  float64
#  17  V17     271286 non-null  float64
#  18  V18     271286 non-null  float64
#  19  V19     271286 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    270805
# 1.0       481
# Name: count, dtype: int64

# %% [markdown]
# This Dataset is highly unblanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (270805, 31)
# (481, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    270805.000000
# mean         89.256037
# std         247.420484
# min           0.000000
# 25%           5.950000
# 50%          22.610000
# 75%          78.590000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     481.000000
# mean      121.239605
# std       257.722080
# min         0.000000
# 25%         1.000000
# 50%         8.640000
# 75%       104.810000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    91177.538506  0.000672 -0.019150  0.050389 -0.000074 -0.009064
# 1.0    78754.848233 -4.843897  3.709169 -7.124813  4.604331 -3.241169
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.009098  0.003286 -0.001187  0.004646  ...  0.000542 -0.001493
# 1.0   -1.403691 -5.660080  0.613744 -2.620426  ...  0.370551  0.737419
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.003805 -0.001714  0.000904  0.007281  0.000388 -0.000572  0.000389
# 1.0    0.004536 -0.051545 -0.110216  0.047133  0.049161  0.164155  0.074541
#
#            Amount
# Class
# 0.0     89.256037
# 1.0    121.239605
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 174437  121912.0 -2.057464  1.944087 -0.632438 -2.434445 -0.466172 -1.661359
# 260895  159768.0 -2.521256  2.950948 -0.964622 -0.814840 -0.359423  0.455675
# 141113   84127.0 -0.318530  0.060066  1.996844  0.871457 -1.084420  0.453129
# 66969    52305.0  1.094900  0.170937  0.012478  1.118953 -0.018556 -0.583053
# 3024      2576.0 -0.489319  0.948805  1.438957 -0.210959  0.202546 -0.365122
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 174437  0.197623  1.085982 -0.005259  ... -0.210255 -0.819188  0.064120
# 260895 -1.718790 -6.832341  0.288605  ...  6.664253 -2.861599  1.154956
# 141113 -0.006545  0.105512 -1.679202  ... -0.007116  0.497413  0.059922
# 66969   0.371606 -0.153578 -0.117325  ...  0.032939  0.026750 -0.115861
# 3024    0.674020  0.059537 -0.743545  ... -0.176425 -0.488874 -0.035665
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 263080  160791.0  2.132386  0.705608 -3.530759  0.514779  1.527175 -1.716268
# 263274  160870.0 -0.644278  5.002352 -8.252739  7.756915 -0.216267 -2.751496
# 263324  160895.0 -0.848290  2.719882 -6.199070  3.044437 -3.301910 -1.992117
# 263877  161154.0 -3.387601  3.977881 -6.978585  1.657766 -1.100500 -3.599487
# 268375  163181.0 -5.238808  0.623013 -5.784507  1.678889 -0.364432 -0.477295
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 263080  1.132791 -0.574214  0.128904  ...  0.163739  0.703910 -0.245076
# 263274 -3.358857  1.406268 -4.403852  ...  0.587728 -0.605759  0.033746
# 263324 -3.734902  1.520079 -2.548788  ...  1.125229  0.805258  0.199119
# 263877 -3.686651  1.942252 -3.065089  ...  1.043587  0.262189 -0.479224
# 268375 -4.276132 -0.695173 -2.971644  ... -0.326140  1.509239 -0.215966
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    481
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    90478.790650  0.012479  0.038437  0.187667  0.031204 -0.059476
# 1.0    78754.848233 -4.843897  3.709169 -7.124813  4.604331 -3.241169
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.010346 -0.091908 -0.104797  0.015433  ...  0.022366  0.000949
# 1.0   -1.403691 -5.660080  0.613744 -2.620426  ...  0.370551  0.737419
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.033266  0.020950  0.030299  0.004288 -0.016764 -0.005878 -0.006662
# 1.0    0.004536 -0.051545 -0.110216  0.047133  0.049161  0.164155  0.074541
#
#            Amount
# Class
# 0.0     78.207785
# 1.0    121.239605
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 174437  121912.0 -2.057464  1.944087 -0.632438 -2.434445 -0.466172 -1.661359
# 260895  159768.0 -2.521256  2.950948 -0.964622 -0.814840 -0.359423  0.455675
# 141113   84127.0 -0.318530  0.060066  1.996844  0.871457 -1.084420  0.453129
# 66969    52305.0  1.094900  0.170937  0.012478  1.118953 -0.018556 -0.583053
# 3024      2576.0 -0.489319  0.948805  1.438957 -0.210959  0.202546 -0.365122
# ...          ...       ...       ...       ...       ...       ...       ...
# 263080  160791.0  2.132386  0.705608 -3.530759  0.514779  1.527175 -1.716268
# 263274  160870.0 -0.644278  5.002352 -8.252739  7.756915 -0.216267 -2.751496
# 263324  160895.0 -0.848290  2.719882 -6.199070  3.044437 -3.301910 -1.992117
# 263877  161154.0 -3.387601  3.977881 -6.978585  1.657766 -1.100500 -3.599487
# 268375  163181.0 -5.238808  0.623013 -5.784507  1.678889 -0.364432 -0.477295
#
# ...

# %%
print(Y)
# Out:
# 174437    0.0
# 260895    0.0
# 141113    0.0
# 66969     0.0
# 3024      0.0
#          ...
# 263080    1.0
# 263274    1.0
# 263324    1.0
# 263877    1.0
# 268375    1.0
# Name: Class, Length: 973, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (973, 30) (778, 30) (195, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9485861182519281

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9230769230769231

# %%
# Example input (you can replace this with actual values later)
input_data = (0.0, -1.359807, -0.072781, 2.536347, 1.378155, -0.338321, 0.462388,
              0.239599, 0.098698, 0.363787, 0.090794, -0.551600, -0.617801, -0.991390,
              -0.311169, 1.468177, -0.470400, 0.207971, 0.025791, 0.403993, 0.251412,
              -0.018307, 0.277838, -0.110474, 0.066928, 0.128539, -0.189115, 0.133558,
              -0.021053, 149.62)

# Convert to NumPy array and reshape (1 sample, 30 features)
input_data_np = np.asarray(input_data).reshape(1, -1)

# Predict
prediction = model.predict(input_data_np)

# Output
if prediction[0] == 1:
    print("Transaction is Legit.")
else:
    print("Transaction is Fraudulent.")
# Out:
# Transaction is Fraudulent.
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
